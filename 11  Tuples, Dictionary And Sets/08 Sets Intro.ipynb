# %% [markdown]
# Sets Doesn't Support Indexing

# %%
a = {"Apple", 25, 2.5}
print(a)
# Out:
# {25, 2.5, 'Apple'}

# %% [markdown]
# In The Above Output We Can See That The Order Is Not Maintained. In Sets Order Is Not Maintained

# %%
s = {}
type(s)
# Out:
# dict

# %% [markdown]
# To Create An Empty Set We Need To Use TypeCasting

# %%
s.add("Hi")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/harshprasad/Movies/Study/Python/Python-Codes/11  Tuples, Dictionary And Sets/08 Sets Intro.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/harshprasad/Movies/Study/Python/Python-Codes/11%20%20Tuples%2C%20Dictionary%20And%20Sets/08%20Sets%20Intro.ipynb#ch0000023?line=0'>1</a> s.add("Hi")
#
# AttributeError: 'dict' object has no attribute 'add'

# %%
s = set()
s.add("hello")
s
# Out:
# {'hello'}

# %%
type(a)
# Out:
# set

# %%
23 in a
# Out:
# False

# %%
"Apple" in a
# Out:
# True

# %%
for v in a:
  print(v)
# Out:
# 25
# 2.5
# Apple

# %%
len(a)
# Out:
# 3

# %% [markdown]
# Add And Update Data In A Set

# %%
a.add("Banana")
print(a)
# Out:
# {25, 2.5, 'Banana', 'Apple'}

# %%
b = {"Banana", "Mango"}
a.update(b)
print(a)
# Out:
# {2.5, 'Apple', 'Mango', 25, 'Banana'}

# %% [markdown]
# Removing Data From Set

# %%
a.remove(2.5)
print(a)
# Out:
# {'Apple', 'Mango', 25, 'Banana'}

# %%
a.remove("cat")
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/harshprasad/Movies/Study/Python/Python-Codes/11  Tuples, Dictionary And Sets/08 Sets Intro.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/harshprasad/Movies/Study/Python/Python-Codes/11%20%20Tuples%2C%20Dictionary%20And%20Sets/08%20Sets%20Intro.ipynb#ch0000014?line=0'>1</a> a.remove("cat")
#       <a href='vscode-notebook-cell:/Users/harshprasad/Movies/Study/Python/Python-Codes/11%20%20Tuples%2C%20Dictionary%20And%20Sets/08%20Sets%20Intro.ipynb#ch0000014?line=1'>2</a> print(a)
#
# KeyError: 'cat'

# %%
a.discard("cat")

# %% [markdown]
# Both Remove And Discard Removes The Element Except That The Discard Function Doesn't Throw Error

# %%
print(a.pop())
print(a)
# Out:
# Apple
# {'Mango', 25, 'Banana'}

# %% [markdown]
# Pop Function Removes Any Random Element And Doesn't Take Any Argument In Sets

# %%
a.clear()
print(a)
# Out:
# set()

# %%
del a
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/harshprasad/Movies/Study/Python/Python-Codes/11  Tuples, Dictionary And Sets/08 Sets Intro.ipynb Cell 20' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/harshprasad/Movies/Study/Python/Python-Codes/11%20%20Tuples%2C%20Dictionary%20And%20Sets/08%20Sets%20Intro.ipynb#ch0000020?line=0'>1</a> del a
# ----> <a href='vscode-notebook-cell:/Users/harshprasad/Movies/Study/Python/Python-Codes/11%20%20Tuples%2C%20Dictionary%20And%20Sets/08%20Sets%20Intro.ipynb#ch0000020?line=1'>2</a> print(a)
#
# NameError: name 'a' is not defined
