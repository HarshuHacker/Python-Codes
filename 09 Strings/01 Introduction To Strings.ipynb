# %% [markdown]
# In Python The Encoding Is Done Using Unicodes Whereas In C++ and Java Encoding Is Done Using ASCII Values

# %%
s = "Harsh"
print(s)
# Out:
# Harsh

# %%
s = 'Harsh'
print(s)
# Out:
# Harsh

# %% [markdown]
# In Case Of Triple Quote We Can Initialize Multiline Strings Which Can Not Be Done Using Single Or Double Quotes

# %%
s = '''My Name
Is Harsh 
Prasad'''
print(s)
print(s[0])
print(s[5])
print(s[-2])
s
# Out:
# My Name
# Is Harsh
# Prasad
# M
# m
# a
# 'My Name\nIs Harsh \nPrasad'
